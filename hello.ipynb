# %% [markdown]
# <a href="https://colab.research.google.com/github/elpida-p/ilovegit/blob/main/hello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/elpida-p/ilovegit.git
# %cd ilovegit
# Out:
# Cloning into 'ilovegit'...
# ...

# %%
print("hello World")
# Out:
# hello World
